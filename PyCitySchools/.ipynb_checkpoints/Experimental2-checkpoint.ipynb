# %%
# Dependencies and Setup
import pandas as pd

# %%
schools_complete = "Resources/schools_complete.csv"
students_complete = "Resources/students_complete.csv"

# %%
schools_complete_df = pd.read_csv(schools_complete)
students_complete_df = pd.read_csv(students_complete)
# schools_complete_df
# students_complete_df

# %%
# students_complete_df["mathsresult"] = students_complete_df["maths_score"].apply(lambda x: 'fail' if x <= 50 else 'pass')
# students_complete_df

bins = [0, 49.9, 100]
group_names = [0, 1]
pd.cut(students_complete_df["maths_score"], bins, labels=group_names).head()
pd.cut(students_complete_df["reading_score"], bins, labels=group_names).head()
students_complete_df["maths_result"] = pd.cut(students_complete_df["maths_score"], bins, labels=group_names)
students_complete_df["maths_result"] = students_complete_df["maths_result"].astype(float)
students_complete_df["reading_result"] = pd.cut(students_complete_df["reading_score"], bins, labels=group_names)
students_complete_df["reading_result"] = students_complete_df["reading_result"].astype(float)
# students_complete_df

# %%
students_complete_df.loc[(students_complete_df['maths_result'] + students_complete_df['reading_result']) > 1, 'total_result'] = '1' 
students_complete_df.loc[(students_complete_df['maths_result'] + students_complete_df['reading_result']) <= 1, 'total_result'] = '0' 
students_complete_df["total_result"] = students_complete_df["total_result"].astype(float)
students_complete_df
# Out:
#        Student ID     student_name gender  year         school_name  \
# 0               0     Paul Bradley      M     9   Huang High School
# 1               1     Victor Smith      M    12   Huang High School
# 2               2  Kevin Rodriguez      M    12   Huang High School
# 3               3    Richard Scott      M    12   Huang High School
# 4               4       Bonnie Ray      F     9   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F    12  Thomas High School
# 39166       39166        Dawn Bell      F    10  Thomas High School
# 39167       39167   Rebecca Tanner      F     9  Thomas High School
# 39168       39168     Desiree Kidd      F    10  Thomas High School
# 39169       39169  Carolyn Jackson      F    11  Thomas High School
#
#        reading_score  maths_score  maths_result  reading_result  total_result
# 0                 96           94           1.0             1.0           1.0
# 1                 90           43           0.0             1.0           0.0
# 2                 41           76           1.0             0.0           0.0
# 3                 89           86           1.0             1.0           1.0
# 4                 87           69           1.0             1.0           1.0
# ...              ...          ...           ...             ...           ...
# 39165             51           48           0.0             1.0           0.0
# 39166             81           89           1.0             1.0           1.0
# 39167             99           99           1.0             1.0           1.0
# 39168             72           77           1.0             1.0           1.0
# 39169             47           62           1.0             0.0           0.0
#
# [39170 rows x 10 columns]

# %%
# schools_complete_df["budget"] = schools_complete_df["budget"].astype(float).map("${:,.2f}".format)
# schools_complete_df.head()

# %%
merged_school_data_df = pd.merge(schools_complete_df, students_complete_df, on="school_name")
# merged_school_data_df

# %%
grouped_data = merged_school_data_df.groupby(["school_name"])
grouped_data.head()
# Out:
#        School ID         school_name         type  size   budget  Student ID  \
# 0              0   Huang High School   Government  2917  1910635           0
# 1              0   Huang High School   Government  2917  1910635           1
# 2              0   Huang High School   Government  2917  1910635           2
# 3              0   Huang High School   Government  2917  1910635           3
# 4              0   Huang High School   Government  2917  1910635           4
# ...          ...                 ...          ...   ...      ...         ...
# 37535         14  Thomas High School  Independent  1635  1043130       37535
# 37536         14  Thomas High School  Independent  1635  1043130       37536
# 37537         14  Thomas High School  Independent  1635  1043130       37537
# 37538         14  Thomas High School  Independent  1635  1043130       37538
# 37539         14  Thomas High School  Independent  1635  1043130       37539
#
#           student_name gender  year  reading_score  maths_score  maths_result  \
# 0         Paul Bradley      M     9             96           94           1.0
# 1         Victor Smith      M    12             90           43           0.0
# 2      Kevin Rodriguez      M    12             41           76           1.0
# 3        Richard Scott      M    12             89           86           1.0
# 4           Bonnie Ray      F     9             87           69           1.0
# ...                ...    ...   ...            ...          ...           ...
# 37535       Norma Mata      F    10             58           98           1.0
# 37536      Cody Miller      M    11             51           93           1.0
# 37537      Erik Snyder      M     9             72           60           1.0
# 37538   Tanya Martinez      F     9             68           86           1.0
# 37539    Noah Erickson      M     9             73           72           1.0
#
#        reading_result  total_result
# 0                 1.0           1.0
# 1                 1.0           0.0
# 2                 0.0           0.0
# 3                 1.0           1.0
# 4                 1.0           1.0
# ...               ...           ...
# 37535             1.0           1.0
# 37536             1.0           1.0
# 37537             1.0           1.0
# 37538             1.0           1.0
# 37539             1.0           1.0
#
# [75 rows x 14 columns]

# %%
# school_df = grouped_data.sum()
# school_df
# school_df[maths_score].mean()

# %%
df = merged_school_data_df.groupby('school_name', as_index=False).agg({"student_name":"count", 'budget':'mean', 'maths_score':'mean', "reading_score":"mean","maths_result":"mean","reading_result":"mean","total_result":"mean"})

# %%
df['per_student_budget'] = df['budget'] / df['student_name']
df
# Out:
#               school_name  student_name     budget  maths_score  \
# 0      Bailey High School          4976  3124928.0    72.352894
# 1     Cabrera High School          1858  1081356.0    71.657158
# 2    Figueroa High School          2949  1884411.0    68.698542
# 3        Ford High School          2739  1763916.0    69.091274
# 4     Griffin High School          1468   917500.0    71.788147
# 5   Hernandez High School          4635  3022020.0    68.874865
# 6      Holden High School           427   248087.0    72.583138
# 7       Huang High School          2917  1910635.0    68.935207
# 8     Johnson High School          4761  3094650.0    68.843100
# 9        Pena High School           962   585858.0    72.088358
# 10  Rodriguez High School          3999  2547363.0    72.047762
# 11    Shelton High School          1761  1056600.0    72.034072
# 12     Thomas High School          1635  1043130.0    69.581651
# 13     Wilson High School          2283  1319574.0    69.170828
# 14     Wright High School          1800  1049400.0    72.047222
#
#     reading_score  maths_result  reading_result  total_result  \
# 0       71.008842      0.916399        0.873794      0.800844
# 1       71.359526      0.908504        0.890743      0.807858
# 2       69.077993      0.816548        0.828077      0.676501
# 3       69.572472      0.824388        0.822198      0.674699
# 4       71.245232      0.912125        0.884877      0.813351
# 5       69.186408      0.809493        0.818770      0.663646
# 6       71.660422      0.899297        0.885246      0.789227
# 7       68.910525      0.816935        0.814535      0.667124
# 8       69.039277      0.820626        0.819786      0.671918
